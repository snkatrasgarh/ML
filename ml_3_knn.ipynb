# %% [markdown]
# <a href="https://colab.research.google.com/github/snkatrasgarh/ML/blob/main/ml_3_knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/iris.csv')
print(data)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
sns.pairplot(data,hue="variety")

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0,shuffle=True)

# %%
from sklearn.neighbors import KNeighborsClassifier
knnmodel=KNeighborsClassifier(n_neighbors=7)
knnmodel.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
inp=[[4,2,2,.2]]
yp=knnmodel.predict(inp)
print(yp)
# Out:
# ['Setosa']

# %%
from sklearn.metrics import classification_report
cr=classification_report(y_test,knnmodel.predict(x_test))
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        11
#   Versicolor       1.00      1.00      1.00        13
#    Virginica       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
